# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
print(len(list(pd.__all__)))
pds = list(pd.__all__)

df = pd.DataFrame()

for p in range(1,10):
    for q in range(1,10):
        print(p, pds, end=",")
    print()
# Out:
# 114
# ...

# %% [markdown]
# ## Creating DataFrames

# %%
import pandas as pd

pd.DataFrame({'A': [1, 2, 3]})
# Out:
#    A
# 0  1
# 1  2
# 2  3
