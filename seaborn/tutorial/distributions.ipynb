# %% [markdown]
# ### Distributions
#
# https://seaborn.pydata.org/tutorial/distributions.html

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.set_theme()

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=3)

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=10)

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=1 )

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=0.1)

# %%
sns.displot(penguins, x="flipper_length_mm", bins=20)

# %%
sns.displot(penguins, x="flipper_length_mm", bins=20)

# %%
tips = sns.load_dataset("tips")
sns.displot(tips, x="size")

# %%
sns.displot(tips, x="size", bins=[1, 2, 3, 4, 5, 6, 7])

# %%
sns.displot(tips, x="size", discrete=True)

# %%
sns.displot(tips, x="size", discrete=False)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(tips, x="sex", discrete=True)

# %%
sns.displot(tips, x="total_bill", discrete=True)

# %%
sns.displot(tips, x="day", shrink=.5)

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", element="step")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", kind='kde')

# %%
sns.displot(penguins, x="flipper_length_mm", hue="sex", multiple="dodge")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="sex")

# %%
sns.displot(penguins, x="flipper_length_mm", col="sex")

# %%
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="density")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="density", col="sex")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="density", common_norm=False)

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="density", common_norm=False, col="sex")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species",  common_norm=False, col="sex")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", stat="probability")
